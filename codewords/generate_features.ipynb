# %%
import pandas as pd
import re

# %% [markdown]
# # Pre-Study Processing

# %%
responses = pd.read_csv('pre_study.csv')
responses.head()
# Out:
#             Timestamp  Participant ID  \
# 0  8/27/2018 13:35:09              11
# 1  8/28/2018 13:20:17             111
# 2  8/28/2018 14:25:33             112
# 3  8/28/2018 16:20:32             113
# 4   8/29/2018 9:20:46             211
#
#   I have read and signed the Informed Consent Form.   Age  Gender  \
# 0                                                Yes   20    Male
# 1                                                Yes   20  Female
# 2                                                Yes   20    Male
# 3                                                Yes   21    Male
# 4                                                Yes   18  Female
#
#   If currently a student, what academic degree and program of study are you currently pursuing? What is your degree progress?   \
# 0  4th year B.A. Computer Science, Cognitive Science
# 1                 B.A. in Computer Science, 3rd year
# 2                        B.S. Mechanical Engineering
# 3  B.A. in Cognitive Science, B.S. in Business Ad...
# 4           B.S. in Mechanical Engineering, 3rd year
#
#   If you've worked in industry, what was your position and how long did you spend in this role?  \
# 0                    Deep learning intern (3 months)
# 1  Software Development Engineer Intern for 3 months
# 2  4 summers doing robotics design, 1 year doing ...
# 3  2 internships: Advertising Design at Spotify; ...
# 4                                                NaN
#
#   How many years of experience do you have programming?  \
# 0                                                  6
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  7
#
#    About how many hours a week do you engage in programming?  \
# 0                                                 12
# 1                                                  6
# 2                                                  3
# 3                                                  0
# 4                                                  8
#
#   Which describe your programming background and style? (Check all that apply)  \
# 0  Early-exposure (Middle/high school clubs/class...
# 1  Early-exposure (Middle/high school clubs/class...
# 2  Light University-exposure (1-2 programming cla...
# 3  DIY Programmer ("Picked it up along the way"),...
# 4  Early-exposure (Middle/high school clubs/class...
#
#                                              ...                                              \
# 0                                            ...
# 1                                            ...
# 2                                            ...
# 3                                            ...
# 4                                            ...
#
#   I am comfortable with programming in these domains. Please mark N/A if you don't have experience in these. [Installation Work]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Rate the following statements: [I consider myself a member of the CS community.]  \
# 0                                           Option 1
# 1                                          4 - Agree
# 2                                        3 - Neutral
# 3                                       2 - Disagree
# 4                                        3 - Neutral
#
#   Rate the following statements: [I feel comfortable writing code from scratch]  \
# 0                                                NaN
# 1                                        3 - Neutral
# 2                                        3 - Neutral
# 3                                       2 - Disagree
# 4                                          4 - Agree
#
#   Rate the following statements: [I need a code skeleton to get started when I code.]  \
# 0                                                NaN
# 1                                        3 - Neutral
# 2                                          4 - Agree
# 3                                          4 - Agree
# 4                                       2 - Disagree
#
#   Rate the following statements: [I feel comfortable using version control to manage my code and/or work collaboratively.]  \
# 0                                                NaN
# 1                                          4 - Agree
# 2                                          4 - Agree
# 3                                          4 - Agree
# 4                                          4 - Agree
#
#   Rate the following statements: [I feel capable as a programmer.]  \
# 0                                                NaN
# 1                                        3 - Neutral
# 2                                          4 - Agree
# 3                                        3 - Neutral
# 4                                        3 - Neutral
#
#   Rate the following statements: [I feel accepted by my peers.]  \
# 0                                                NaN
# 1                                        3 - Neutral
# 2                                          4 - Agree
# 3                                          4 - Agree
# 4                                          4 - Agree
#
#   Rate the following statements: [I feel comfortable sharing my code with others.]  \
# 0                                                NaN
# 1                                        3 - Neutral
# 2                                          4 - Agree
# 3                                          4 - Agree
# 4                                          4 - Agree
#
#   What was the last time you used Python? Describe what it was for.  \
# 0                              Yesterday. This study
# 1                    Spring 2018 semester for CS 188
# 2  Summer 2018. I used it to program a 1D underwa...
# 3  The last time I used Python was in the Spring ...
# 4  Personal project, getting data from an API and...
#
#   Can you describe a project where you used Jupyter Notebooks?  Please describe the process.
# 0  I wrote a Jupyter Notebook logging extension f...
# 1  EE16A labs used Jupyter Notebooks -- they prov...
# 2       in EE16A we used them for homeworks and labs
# 3  In COG SCI 131, I used Jupyter Notebooks to pr...
# 4  EE16B labs/homeworks. Open anaconda, open jupy...
#
# [5 rows x 63 columns]

# %%
output_features = ['ID', 'Age', 'Gender',
                   'Bachelor_EECS', 'Bachelor_other', 'PhD_EECS', 'PhD_other', 
                   'Industry_Experience','Years_Programming', 'Hours_Programming_Per_Week',
                   'Early_Exposure', 'Light_Exposure', 'Heavy_Exposure', 'DIY_progranner', 'Book_learner', 
                   'Lecture_learner', 'Web_learner', 'PSet_learner', 'Project_learner', 'Group_project_learner',
                   'Collaborative_learner', 'Independent_learner', 'OH_attendee',
                   'Java', 'Python', 'C', 'Ruby', 'Javascript', 'C#', 'PHP', 'Obj-C', 'SQL', 'Swift', 
                   'C++', 'R', 'Scala', 'Go', 'HTML/CSS', 'Markup',
                   'Recursion', 'Iteration', 'Arrays', 'Hash_Map/Table', 'Dictionaries', 'Tree/Graph_Traversal', 
                   'Mem_Mgmt', 'Caches', 'Dynamic_Programming', 'Sorting_Searching', 'Stacks_Queues', 'Bit_twiddling', 'Regex', 
                   'Data_Processing', 'Graphics', 'Web_Apps', 'Web_Dev', 'OS_Mgmt', 'Network_System_Mgmt', 'Interactive_Device_Design', 
                   'Obj/Img/Activity_Recognition', 'Robotics', 'NLP', 'Interface_Prototyping', 'Vision_Sim', 'Software_App', 
                   'AR/VR', 'Installation_Work',
                   'Member_CS_Community', 'Comfortable_from_scratch', 'Need_skeleton', 'Comfortable_version_control',
                   'Capable_programmer', 'Accepted_by_peers', 'Comfortable_sharing']

# %%
def Bachelor(text):
    if type(text) is not str:
        return False
    
    return 'B.A.' in text or 'B.S.' in text

def PhD(text):
    if type(text) is not str:
        return False
    
    return 'phd' in text.lower() or "Ph.D." in text

def EECS(text):
    if type(text) is not str:
        return False
    
    return 'EECS' in text or 'Computer Science' in text or 'Electrical Engineering' in text

# %%
def process_likert(text):
    if type(text) is float:
        return 0
    else:
        return int(text[0])

# %%
def process_features(row):
    feats = {}
    feats['ID'] = row[1]
    feats['Age'] = row[3]
    feats['Gender'] = int(row[4] == 'Female')
    
    feats['Bachelor_EECS'] = int(Bachelor(row[5]) and EECS(row[5]))
    feats['Bachelor_other'] = int(Bachelor(row[5]) and not EECS(row[5]))
    feats['PhD_EECS'] = int(PhD(row[5]) and EECS(row[5]))
    feats['PhD_other'] = int(PhD(row[5]) and not EECS(row[5]))
    
    feats["Industry_Experience"] = int(type(row[6]) is str)
    try:
        feats['Years_Programming'] = float(row[7])
    except:
        feats['Years_Programming'] = float(re.findall(r'[0-9]+',row[7])[0]) 
    feats['Hours_Programming_Per_Week'] = int(row[8])
    
    feats['Early_Exposure'] = int('Early-exposure' in row[9])
    feats['Light_Exposure'] = int('Light University-exposure' in row[9])
    feats['Heavy_Exposure'] = int('Heavy University-exposure' in row[9])
    feats['DIY_progranner'] = int('DIY Programmer' in row[9])
    feats['Book_learner'] = int('Book-learner' in row[9])
    feats['Lecture_learner'] = int('Lecture-learner ' in row[9] or 'Lecture learner' in row[9])
    feats['Web_learner'] = int('Web-learner' in row[9])
    feats['PSet_learner'] = int('Problem set learner' in row[9])
    feats['Project_learner'] = int('Project learner' in row[9])
    feats['Group_project_learner'] = int('Group project learner' in row[9])
    feats['Collaborative_learner'] = int('Collaborative learner' in row[9])
    feats['Independent_learner'] = int('Independent learner ' in row[9])
    feats['OH_attendee'] = int('Office hours attendee' in row[9])
    
    i = 10
    for label in output_features[23:]:
        feats[label] = process_likert(row[i])
        i += 1
    
    return feats

# %%
featurized = pd.DataFrame(columns=output_features)
for idx, row in responses.iterrows():
    if idx == 0: # Matt's response
        continue
    features = process_features(row)
    featurized = featurized.append(features, ignore_index=True)

# %%
for label in output_features:
    if label != 'Hours_Programming_Per_Week':
        featurized[label] = featurized[label].astype(int)

# %%
featurized
# Out:
#      ID  Age  Gender  Bachelor_EECS  Bachelor_other  PhD_EECS  PhD_other  \
# 0   111   20       1              1               0         0          0
# 1   112   20       0              0               1         0          0
# 2   113   21       0              0               1         0          0
# 3   211   18       1              0               1         0          0
# 4   212   27       0              0               0         0          0
# 5   214   25       0              0               0         1          0
# 6   411   19       1              1               0         0          0
# 7   412   19       0              0               0         0          0
# 8   413   19       0              0               0         0          0
# 9   414   18       0              0               1         0          0
# 10  512   20       1              1               0         0          0
# 11  613   23       0              0               0         1          0
# 12  614   43       1              0               0         1          0
# 13  711   20       1              1               0         0          0
# 14  713   19       0              1               0         0          0
# 15  813   22       1              0               1         0          0
# 16  811   21       1              0               0         0          0
#
#     Industry_Experience  Years_Programming  Hours_Programming_Per_Week  \
# 0                     1                  3                         6.0
# 1                     1                  4                         3.0
# 2                     1                  3                         0.0
# 3                     0                  7                         8.0
# 4                     1                  6                         2.0
# 5                     1                  7                        20.0
# 6                     1                  7                        10.0
# 7                     0                  2                         5.0
# 8                     1                  3                        10.0
# 9                     0                  1                         3.0
# 10                    1                  2                        20.0
# 11                    1                  6                        30.0
# 12                    1                 20                        20.0
# 13                    1                  2                        20.0
# 14                    0                 10                        30.0
# 15                    1                  4                         8.0
# 16                    1                  5                         5.0
#
#            ...           Software_App  AR/VR  Installation_Work  \
# 0          ...                      4      4                  0
# 1          ...                      3      2                  0
# 2          ...                      0      0                  0
# 3          ...                      0      0                  0
# 4          ...                      5      2                  4
# 5          ...                      5      0                  0
# 6          ...                      4      2                  2
# 7          ...                      4      3                  1
# 8          ...                      5      1                  0
# 9          ...                      0      0                  0
# 10         ...                      5      0                  3
# 11         ...                      4      3                  3
# 12         ...                      5      2                  1
# 13         ...                      0      0                  3
# 14         ...                      4      2                  3
# 15         ...                      3      0                  0
# 16         ...                      4      1                  3
#
#     Member_CS_Community  Comfortable_from_scratch  Need_skeleton  \
# 0                     4                         3              3
# 1                     3                         3              4
# 2                     2                         2              4
# 3                     3                         4              2
# 4                     2                         5              1
# 5                     4                         4              2
# 6                     4                         4              2
# 7                     4                         4              2
# 8                     4                         5              1
# 9                     4                         3              4
# 10                    5                         4              3
# 11                    5                         4              2
# 12                    5                         5              1
# 13                    5                         4              2
# 14                    3                         5              1
# 15                    4                         5              3
# 16                    4                         3              2
#
#     Comfortable_version_control  Capable_programmer  Accepted_by_peers  \
# 0                             4                   3                  3
# 1                             4                   4                  4
# 2                             4                   3                  4
# 3                             4                   3                  4
# 4                             5                   5                  5
# 5                             5                   5                  5
# 6                             5                   4                  4
# 7                             4                   4                  4
# 8                             5                   4                  4
# 9                             3                   3                  4
# 10                            3                   4                  5
# 11                            5                   4                  4
# 12                            5                   5                  5
# 13                            4                   3                  4
# 14                            5                   4                  4
# 15                            5                   3                  3
# 16                            3                   3                  4
#
#     Comfortable_sharing
# 0                     3
# 1                     4
# 2                     4
# 3                     4
# 4                     5
# 5                     5
# 6                     5
# 7                     4
# 8                     5
# 9                     3
# 10                    5
# 11                    4
# 12                    5
# 13                    4
# 14                    3
# 15                    4
# 16                    3
#
# [17 rows x 74 columns]

# %% [markdown]
# # Pre-Study Stats

# %%
demographics = output_features[1:3]
degrees = output_features[3:7]
programming_experience = output_features[7:10]
learning_types = output_features[10:23]
programming_languages = output_features[23:38]
programming_concepts = output_features[38:52]
programming_domains = output_features[52:67]
soft_hard = output_features[67:]

# %%
# Gender = 1 <--> female
featurized[demographics].describe()
# Out:
#              Age     Gender
# count  17.000000  17.000000
# mean   22.000000   0.470588
# std     5.926635   0.514496
# min    18.000000   0.000000
# 25%    19.000000   0.000000
# 50%    20.000000   0.000000
# 75%    22.000000   1.000000
# max    43.000000   1.000000

# %%
featurized[degrees].describe()
# Out:
#        Bachelor_EECS  Bachelor_other   PhD_EECS  PhD_other
# count      17.000000       17.000000  17.000000       17.0
# mean        0.294118        0.294118   0.176471        0.0
# std         0.469668        0.469668   0.392953        0.0
# min         0.000000        0.000000   0.000000        0.0
# 25%         0.000000        0.000000   0.000000        0.0
# 50%         0.000000        0.000000   0.000000        0.0
# 75%         1.000000        1.000000   0.000000        0.0
# max         1.000000        1.000000   1.000000        0.0

# %%
featurized[programming_experience].describe()
# Out:
#        Industry_Experience  Years_Programming  Hours_Programming_Per_Week
# count            17.000000          17.000000                   17.000000
# mean              0.764706           5.411765                   11.764706
# std               0.437237           4.458963                    9.627626
# min               0.000000           1.000000                    0.000000
# 25%               1.000000           3.000000                    5.000000
# 50%               1.000000           4.000000                    8.000000
# 75%               1.000000           7.000000                   20.000000
# max               1.000000          20.000000                   30.000000

# %%
featurized[learning_types].describe()
# Out:
#        Early_Exposure  Light_Exposure  Heavy_Exposure  DIY_progranner  \
# count       17.000000       17.000000       17.000000       17.000000
# mean         0.411765        0.058824        0.705882        0.529412
# std          0.507300        0.242536        0.469668        0.514496
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          0.000000        0.000000        1.000000        1.000000
# 75%          1.000000        0.000000        1.000000        1.000000
# max          1.000000        1.000000        1.000000        1.000000
#
#        Book_learner  Lecture_learner  Web_learner  PSet_learner  \
# count     17.000000        17.000000    17.000000     17.000000
# mean       0.294118         0.352941     0.470588      0.352941
# std        0.469668         0.492592     0.514496      0.492592
# min        0.000000         0.000000     0.000000      0.000000
# 25%        0.000000         0.000000     0.000000      0.000000
# 50%        0.000000         0.000000     0.000000      0.000000
# 75%        1.000000         1.000000     1.000000      1.000000
# max        1.000000         1.000000     1.000000      1.000000
#
#        Project_learner  Group_project_learner  Collaborative_learner  \
# count        17.000000              17.000000              17.000000
# mean          0.823529               0.176471               0.529412
# std           0.392953               0.392953               0.514496
# min           0.000000               0.000000               0.000000
# 25%           1.000000               0.000000               0.000000
# 50%           1.000000               0.000000               1.000000
# 75%           1.000000               0.000000               1.000000
# max           1.000000               1.000000               1.000000
#
#        Independent_learner  OH_attendee
# count            17.000000    17.000000
# mean              0.647059     0.176471
# std               0.492592     0.392953
# min               0.000000     0.000000
# 25%               0.000000     0.000000
# 50%               1.000000     0.000000
# 75%               1.000000     0.000000
# max               1.000000     1.000000

# %%
featurized[programming_languages].describe()
# Out:
#             Java     Python          C       Ruby  Javascript         C#  \
# count  17.000000  17.000000  17.000000  17.000000   17.000000  17.000000
# mean    3.764706   4.470588   2.705882   0.941176    3.058824   0.882353
# std     1.393261   0.514496   1.759428   1.088037    1.519481   1.268974
# min     0.000000   4.000000   0.000000   0.000000    0.000000   0.000000
# 25%     3.000000   4.000000   2.000000   0.000000    2.000000   0.000000
# 50%     4.000000   4.000000   3.000000   1.000000    3.000000   0.000000
# 75%     5.000000   5.000000   4.000000   2.000000    4.000000   2.000000
# max     5.000000   5.000000   5.000000   3.000000    5.000000   4.000000
#
#              PHP      Obj-C        SQL      Swift        C++          R  \
# count  17.000000  17.000000  17.000000  17.000000  17.000000  17.000000
# mean    1.000000   1.117647   2.529412   1.176471   2.058824   1.000000
# std     1.541104   1.536325   1.419403   1.467791   1.748949   1.224745
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   2.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   3.000000   1.000000   2.000000   1.000000
# 75%     1.000000   2.000000   3.000000   2.000000   4.000000   1.000000
# max     5.000000   4.000000   5.000000   4.000000   5.000000   4.000000
#
#            Scala         Go   HTML/CSS
# count  17.000000  17.000000  17.000000
# mean    1.117647   0.823529   3.352941
# std     1.653872   1.014599   1.538716
# min     0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   2.000000
# 50%     0.000000   0.000000   4.000000
# 75%     1.000000   2.000000   5.000000
# max     5.000000   3.000000   5.000000

# %%
featurized[programming_concepts].describe()
# Out:
#           Markup  Recursion  Iteration     Arrays  Hash_Map/Table  \
# count  17.000000  17.000000  17.000000  17.000000       17.000000
# mean    1.647059   4.117647   4.470588   4.588235        3.411765
# std     1.998161   0.696631   0.717430   0.618347        1.872793
# min     0.000000   3.000000   3.000000   3.000000        0.000000
# 25%     0.000000   4.000000   4.000000   4.000000        3.000000
# 50%     1.000000   4.000000   5.000000   5.000000        4.000000
# 75%     4.000000   5.000000   5.000000   5.000000        5.000000
# max     5.000000   5.000000   5.000000   5.000000        5.000000
#
#        Dictionaries  Tree/Graph_Traversal   Mem_Mgmt     Caches  \
# count     17.000000             17.000000  17.000000  17.000000
# mean       3.764706              3.411765   2.941176   2.411765
# std        1.393261              1.416811   1.297622   1.277636
# min        0.000000              0.000000   0.000000   0.000000
# 25%        3.000000              3.000000   2.000000   2.000000
# 50%        4.000000              4.000000   3.000000   3.000000
# 75%        5.000000              4.000000   4.000000   3.000000
# max        5.000000              5.000000   5.000000   5.000000
#
#        Dynamic_Programming  Sorting_Searching  Stacks_Queues  Bit_twiddling  \
# count            17.000000          17.000000      17.000000      17.000000
# mean              2.294118           3.411765       3.529412       2.882353
# std               1.611083           1.064121       1.545867       1.409005
# min               0.000000           1.000000       0.000000       0.000000
# 25%               2.000000           3.000000       3.000000       2.000000
# 50%               2.000000           4.000000       4.000000       3.000000
# 75%               3.000000           4.000000       4.000000       4.000000
# max               5.000000           5.000000       5.000000       5.000000
#
#            Regex
# count  17.000000
# mean    3.176471
# std     1.185079
# min     1.000000
# 25%     3.000000
# 50%     3.000000
# 75%     4.000000
# max     5.000000

# %%
featurized[programming_domains].describe()
# Out:
#        Data_Processing   Graphics   Web_Apps    Web_Dev    OS_Mgmt  \
# count        17.000000  17.000000  17.000000  17.000000  17.000000
# mean          3.470588   1.705882   2.588235   3.000000   1.470588
# std           1.328422   1.447615   1.970369   1.903943   1.699913
# min           0.000000   0.000000   0.000000   0.000000   0.000000
# 25%           3.000000   0.000000   0.000000   2.000000   0.000000
# 50%           4.000000   2.000000   3.000000   4.000000   1.000000
# 75%           4.000000   3.000000   4.000000   4.000000   2.000000
# max           5.000000   4.000000   5.000000   5.000000   5.000000
#
#        Network_System_Mgmt  Interactive_Device_Design  \
# count            17.000000                  17.000000
# mean              1.294118                   1.941176
# std               1.686887                   1.638238
# min               0.000000                   0.000000
# 25%               0.000000                   0.000000
# 50%               0.000000                   2.000000
# 75%               2.000000                   4.000000
# max               5.000000                   4.000000
#
#        Obj/Img/Activity_Recognition   Robotics        NLP  \
# count                     17.000000  17.000000  17.000000
# mean                       1.882353   1.470588   1.764706
# std                        1.727800   1.504894   1.678147
# min                        0.000000   0.000000   0.000000
# 25%                        0.000000   0.000000   0.000000
# 50%                        2.000000   1.000000   2.000000
# 75%                        3.000000   2.000000   3.000000
# max                        5.000000   5.000000   5.000000
#
#        Interface_Prototyping  Vision_Sim  Software_App      AR/VR  \
# count              17.000000   17.000000     17.000000  17.000000
# mean                2.823529    0.823529      3.235294   1.294118
# std                 1.740521    1.131111      1.953504   1.311712
# min                 0.000000    0.000000      0.000000   0.000000
# 25%                 2.000000    0.000000      3.000000   0.000000
# 50%                 3.000000    0.000000      4.000000   1.000000
# 75%                 4.000000    2.000000      5.000000   2.000000
# max                 5.000000    3.000000      5.000000   4.000000
#
#        Installation_Work
# count          17.000000
# mean            1.352941
# std             1.497547
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             3.000000
# max             4.000000

# %%
featurized[soft_hard].describe()
# Out:
#        Member_CS_Community  Comfortable_from_scratch  Need_skeleton  \
# count            17.000000                 17.000000      17.000000
# mean              3.823529                  3.941176       2.294118
# std               0.951006                  0.899346       1.046704
# min               2.000000                  2.000000       1.000000
# 25%               3.000000                  3.000000       2.000000
# 50%               4.000000                  4.000000       2.000000
# 75%               4.000000                  5.000000       3.000000
# max               5.000000                  5.000000       4.000000
#
#        Comfortable_version_control  Capable_programmer  Accepted_by_peers  \
# count                    17.000000           17.000000          17.000000
# mean                      4.294118            3.764706           4.117647
# std                       0.771744            0.752447           0.600245
# min                       3.000000            3.000000           3.000000
# 25%                       4.000000            3.000000           4.000000
# 50%                       4.000000            4.000000           4.000000
# 75%                       5.000000            4.000000           4.000000
# max                       5.000000            5.000000           5.000000
#
#        Comfortable_sharing
# count            17.000000
# mean              4.117647
# std               0.781213
# min               3.000000
# 25%               4.000000
# 50%               4.000000
# 75%               5.000000
# max               5.000000

# %%
# Returns the response for each ID and aggregated response statistics
# Use this if the above is not informative enough
def get_stats(columns, df=featurized):
    print(df[['ID'] + columns])
    return df[['ID'] + columns].describe()

# %%
get_stats(['Robotics'])
# Out:
#      ID  Robotics
# 0   111         0
# 1   112         5
# 2   113         0
# 3   211         3
# 4   212         1
# 5   214         2
# 6   411         2
# 7   412         1
# 8   413         4
# 9   414         0
# 10  512         0
# 11  613         1
# 12  614         2
# 13  711         0
# 14  713         2
# 15  813         0
# 16  811         2
#                ID   Robotics
# count   17.000000  17.000000
# mean   435.882353   1.470588
# std    246.364284   1.504894
# min    111.000000   0.000000
# 25%    212.000000   0.000000
# 50%    413.000000   1.000000
# 75%    614.000000   2.000000
# max    813.000000   5.000000

# %% [markdown]
# # Post-Study Processing

# %%
post_study = pd.read_csv('post_study.csv')
post_study
# Out:
#              Timestamp  Participant ID  \
# 0   8/28/2018 14:06:22             111
# 1   8/28/2018 15:20:55             112
# 2   8/28/2018 17:12:09             113
# 3   8/29/2018 10:02:15             211
# 4   8/29/2018 14:11:26             212
# 5   8/29/2018 16:13:24             214
# 6   8/31/2018 11:56:13             411
# 7   8/31/2018 12:49:52             412
# 8   8/31/2018 14:25:58             413
# 9   8/31/2018 16:11:15             414
# 10   9/4/2018 17:45:02             512
# 11   9/5/2018 14:39:22             613
# 12   9/5/2018 15:58:03             614
# 13   9/6/2018 14:18:05             711
# 14   9/6/2018 17:19:01             713
# 15   9/7/2018 16:13:45             813
# 16   9/7/2018 17:20:43             811
#
#     How would you rate your overall coding session?  \
# 0                                                 4
# 1                                                 6
# 2                                                 3
# 3                                                 5
# 4                                                 7
# 5                                                 6
# 6                                                 6
# 7                                                 2
# 8                                                 4
# 9                                                 3
# 10                                                7
# 11                                                5
# 12                                                6
# 13                                                6
# 14                                                7
# 15                                                3
# 16                                                4
#
#     Rate the statement: During the coding session, I programmed like I would normally program.  \
# 0                                                   4
# 1                                                   5
# 2                                                   6
# 3                                                   5
# 4                                                   4
# 5                                                   6
# 6                                                   6
# 7                                                   5
# 8                                                   3
# 9                                                   3
# 10                                                  6
# 11                                                  7
# 12                                                  6
# 13                                                  7
# 14                                                  6
# 15                                                  6
# 16                                                  6
#
#     Rate the statement: The wristband affected my ability to code.   \
# 0                                                   5
# 1                                                   1
# 2                                                   1
# 3                                                   6
# 4                                                   1
# 5                                                   4
# 6                                                   2
# 7                                                   1
# 8                                                   4
# 9                                                   4
# 10                                                  2
# 11                                                  1
# 12                                                  2
# 13                                                  1
# 14                                                  2
# 15                                                  1
# 16                                                  2
#
#    We set up your workstation like this. Can you describe how your workstation is similar/different?  \
# 0                          Trackpad. Pretty similar.
# 1   If I'm doing homework I'll often sit on the co...
# 2   I always program on a laptop using the laptop ...
# 3   I almost entirely work on a laptop so this key...
# 4   i have vim keybindings in jupyter notebook, an...
# 5   My desktop has two monitors, although I primar...
# 6   I normally use my laptop, which is a Lenovo Th...
# 7   I normally work on a laptop, not with a monito...
# 8   In my workstation, I usually have 2 monitors a...
# 9   My workstation is with a Windows laptop and wi...
# 10  My workstation is very similar to this, with m...
# 11  Very similar. Font-size might be slightly larg...
# 12  I typically work on my laptop, so my mouse is ...
# 13  Usually I sit on a sofa at home and code on my...
# 14  Similarities: I usually use a single monitor a...
# 15  I code on a mac machine so the keyboard is dif...
# 16  I usually use a laptop. So this workstation (s...
#
#    Is there anything that you do differently that you couldn't do within this setup? e.g. A specific place you program, a specific time, a specific group of people? Would you work longer/shorter?
# 0   Closed room without people; work at night. Hea...
# 1   I usually binge program since as soon as you w...
# 2   I tend to work with noise-canceling headphones...
# 3   no specific places, times, or people. usually ...
# 4   eh,  i listen to music, otherwise i program pr...
# 5   I normally listen to music while I program. Th...
# 6   One difference is that during the session I fo...
# 7   I think this was pretty representative of what...
# 8   I typically program later at night, and work o...
# 9   Generally I listen to music when I am coding a...
# 10  I think the physical setup of this desk, compu...
# 11  I would work a bit longer to add comments and ...
# 12  I would work longer and get the function to wo...
# 13  I usually have water next to me so I can take ...
# 14  No, the setup didn't prevent me from doing any...
# 15  I like working at night. That's usually when m...
# 16  I usually prefer programming alone, and sittin...

# %%
post_study_feats = pd.DataFrame(columns=['ID', 'Overall_Rating', 'Programmed_Normally', 'Wristband'], dtype='float')
for idx, row in post_study.iterrows():
    feats = {'ID': row[1], 
             'Overall_Rating': row[2], 
             'Programmed_Normally': row[3], 
             'Wristband': row[4]}
    post_study_feats = post_study_feats.append(feats, ignore_index=True)

# %%
post_study_feats.describe()
# Out:
#                ID  Overall_Rating  Programmed_Normally  Wristband
# count   17.000000       17.000000            17.000000  17.000000
# mean   435.882353        4.941176             5.352941   2.352941
# std    246.364284        1.599632             1.221739   1.617914
# min    111.000000        2.000000             3.000000   1.000000
# 25%    212.000000        4.000000             5.000000   1.000000
# 50%    413.000000        5.000000             6.000000   2.000000
# 75%    614.000000        6.000000             6.000000   4.000000
# max    813.000000        7.000000             7.000000   6.000000

# %% [markdown]
# # Predicting Success

# %%
f_ = featurized.set_index("ID")
p_ = post_study_feats.set_index("ID")
all_results = f_.join(p_)
all_results
# Out:
#      Age  Gender  Bachelor_EECS  Bachelor_other  PhD_EECS  PhD_other  \
# ID
# 111   20       1              1               0         0          0
# 112   20       0              0               1         0          0
# 113   21       0              0               1         0          0
# 211   18       1              0               1         0          0
# 212   27       0              0               0         0          0
# 214   25       0              0               0         1          0
# 411   19       1              1               0         0          0
# 412   19       0              0               0         0          0
# 413   19       0              0               0         0          0
# 414   18       0              0               1         0          0
# 512   20       1              1               0         0          0
# 613   23       0              0               0         1          0
# 614   43       1              0               0         1          0
# 711   20       1              1               0         0          0
# 713   19       0              1               0         0          0
# 813   22       1              0               1         0          0
# 811   21       1              0               0         0          0
#
#      Industry_Experience  Years_Programming  Hours_Programming_Per_Week  \
# ID
# 111                    1                  3                         6.0
# 112                    1                  4                         3.0
# 113                    1                  3                         0.0
# 211                    0                  7                         8.0
# 212                    1                  6                         2.0
# 214                    1                  7                        20.0
# 411                    1                  7                        10.0
# 412                    0                  2                         5.0
# 413                    1                  3                        10.0
# 414                    0                  1                         3.0
# 512                    1                  2                        20.0
# 613                    1                  6                        30.0
# 614                    1                 20                        20.0
# 711                    1                  2                        20.0
# 713                    0                 10                        30.0
# 813                    1                  4                         8.0
# 811                    1                  5                         5.0
#
#      Early_Exposure    ...      Member_CS_Community  Comfortable_from_scratch  \
# ID                     ...
# 111               1    ...                        4                         3
# 112               0    ...                        3                         3
# 113               0    ...                        2                         2
# 211               1    ...                        3                         4
# 212               0    ...                        2                         5
# 214               0    ...                        4                         4
# 411               1    ...                        4                         4
# 412               0    ...                        4                         4
# 413               1    ...                        4                         5
# 414               0    ...                        4                         3
# 512               1    ...                        5                         4
# 613               0    ...                        5                         4
# 614               1    ...                        5                         5
# 711               0    ...                        5                         4
# 713               1    ...                        3                         5
# 813               0    ...                        4                         5
# 811               0    ...                        4                         3
#
#      Need_skeleton  Comfortable_version_control  Capable_programmer  \
# ID
# 111              3                            4                   3
# 112              4                            4                   4
# 113              4                            4                   3
# 211              2                            4                   3
# 212              1                            5                   5
# 214              2                            5                   5
# 411              2                            5                   4
# 412              2                            4                   4
# 413              1                            5                   4
# 414              4                            3                   3
# 512              3                            3                   4
# 613              2                            5                   4
# 614              1                            5                   5
# 711              2                            4                   3
# 713              1                            5                   4
# 813              3                            5                   3
# 811              2                            3                   3
#
#      Accepted_by_peers  Comfortable_sharing  Overall_Rating  \
# ID
# 111                  3                    3             4.0
# 112                  4                    4             6.0
# 113                  4                    4             3.0
# 211                  4                    4             5.0
# 212                  5                    5             7.0
# 214                  5                    5             6.0
# 411                  4                    5             6.0
# 412                  4                    4             2.0
# 413                  4                    5             4.0
# 414                  4                    3             3.0
# 512                  5                    5             7.0
# 613                  4                    4             5.0
# 614                  5                    5             6.0
# 711                  4                    4             6.0
# 713                  4                    3             7.0
# 813                  3                    4             3.0
# 811                  4                    3             4.0
#
#      Programmed_Normally  Wristband
# ID
# 111                  4.0        5.0
# 112                  5.0        1.0
# 113                  6.0        1.0
# 211                  5.0        6.0
# 212                  4.0        1.0
# 214                  6.0        4.0
# 411                  6.0        2.0
# 412                  5.0        1.0
# 413                  3.0        4.0
# 414                  3.0        4.0
# 512                  6.0        2.0
# 613                  7.0        1.0
# 614                  6.0        2.0
# 711                  7.0        1.0
# 713                  6.0        2.0
# 813                  6.0        1.0
# 811                  6.0        2.0
#
# [17 rows x 76 columns]

# %%
from sklearn import linear_model as lm
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
X = np.asarray(all_results.loc[:, 'Gender':'Comfortable_sharing'])
y = np.asarray(all_results['Overall_Rating'])
scaler = MinMaxScaler()
scaler.fit(X)
scaler.transform(X)
y = (y - np.min(y)) / (np.max(y) - np.min(y))

# %%
model = lm.LinearRegression()
model.fit(X, y)
print(model.score(X, y))
columns = all_results.columns[1:-3]
for i in range(1, len(columns)):
    print(columns[i-1], model.coef_[i])
# Out:
# 1.0
# Gender 0.02401701074206966
# Bachelor_EECS -0.0003314529860138152
# Bachelor_other -0.010516321261368446
# PhD_EECS 2.7755575615628914e-17
# PhD_other 0.012025343938313612
# Industry_Experience 0.011714901345697065
# Years_Programming 0.010167748840261018
# Hours_Programming_Per_Week 0.013919520659723959
# Early_Exposure 0.00824059478767185
# Light_Exposure -0.006427265350101328
# Heavy_Exposure -0.005198437603279097
# DIY_progranner 0.014156215551839189
# Book_learner 0.0033123584002383057
# Lecture_learner 0.0022519694730697183
# Web_learner -0.0047543372709860105
# PSet_learner 0.0076162559613886
# Project_learner 0.003168194557235079
# Group_project_learner -0.009785867923607996
# Collaborative_learner 0.02103605380881994
# Independent_learner 0.00810383614335403
# OH_attendee 0.0166440126582671
# Java -0.009851638529638345
# Python -0.01149693038577722
# C -0.004334289032368415
# Ruby 0.04318261482452068
# Javascript -0.04290136030679254
# C# 0.015480006022547649
# PHP -0.027160006955186302
# Obj-C -0.013705957602571544
# SQL 0.006510948153677919
# Swift -0.007131278097735092
# C++ -0.0036524937833691006
# R 0.0241699748548898
# Scala -0.008971234902001956
# Go 0.0033047259293455373
# HTML/CSS 0.02023219534190133
# Markup 0.0012081140681064972
# Recursion 0.002195330347975641
# Iteration 0.009505158535616773
# Arrays -0.017663138861579854
# Hash_Map/Table 0.003839860084510532
# Dictionaries -0.016119056339903196
# Tree/Graph_Traversal 0.017663609023925362
# Mem_Mgmt -0.0011305127562608597
# Caches -0.026665106558753093
# Dynamic_Programming -0.013178882433491964
# Sorting_Searching -0.018038653174952488
# Stacks_Queues 0.009621544787353668
# Bit_twiddling -0.01510627489123878
# Regex 0.026096886867884812
# Data_Processing 0.006185818390558395
# Graphics 0.007996377076121868
# Web_Apps 0.015028618640630665
# Web_Dev 0.026803631094291052
# OS_Mgmt -0.03140711478264353
# Network_System_Mgmt -0.011789076625421486
# Interactive_Device_Design -0.001086003025342279
# Obj/Img/Activity_Recognition 0.03079019441529996
# Robotics 0.016406217197082823
# NLP 0.03990101147956242
# Interface_Prototyping -0.019774247993858296
# Vision_Sim 0.0009422621387812236
# Software_App -0.03341495141517804
# AR/VR 0.02944382426684408
# Installation_Work -0.004010912497927113
# Member_CS_Community -0.0007977420974386263
# Comfortable_from_scratch 0.008455452369218405
# Need_skeleton -0.009543341213315275
# Comfortable_version_control 0.004738174892501517
# Capable_programmer 0.013324807300884868
# Accepted_by_peers 0.02096753168985525

# %%
# Lasso (L1 regularization) encourages sparse feature selection
model = lm.Lasso(alpha=.1)
model.fit(X, y)
print(model.score(X, y))
columns = all_results.columns[1:-3]
for i in range(1, len(columns)):
    print(columns[i-1], model.coef_[i])
# Out:
# 0.6011351063587493
# Gender 0.0
# Bachelor_EECS -0.0
# Bachelor_other -0.0
# PhD_EECS 0.0
# PhD_other 0.0
# Industry_Experience 0.0009556115578173016
# Years_Programming 0.012714348903000145
# Hours_Programming_Per_Week 0.0
# Early_Exposure 0.0
# Light_Exposure -0.0
# Heavy_Exposure 0.0
# DIY_progranner 0.0
# Book_learner -0.0
# Lecture_learner -0.0
# Web_learner -0.0
# PSet_learner 0.0
# Project_learner -0.0
# Group_project_learner -0.0
# Collaborative_learner 0.0
# Independent_learner 0.0
# OH_attendee -0.0
# Java -0.0
# Python -0.0
# C -0.0
# Ruby 0.03609700866583228
# Javascript -0.019736796891004403
# C# 0.0
# PHP -0.0
# Obj-C -0.0
# SQL 0.0
# Swift 0.0
# C++ -0.0
# R 0.015203763750403486
# Scala 0.0
# Go -0.0
# HTML/CSS 0.0
# Markup 0.0
# Recursion 0.0
# Iteration 0.0
# Arrays -0.0
# Hash_Map/Table 0.0
# Dictionaries -0.0
# Tree/Graph_Traversal 0.0
# Mem_Mgmt -0.0
# Caches -0.0
# Dynamic_Programming -0.0
# Sorting_Searching -0.0
# Stacks_Queues 0.0
# Bit_twiddling -0.0
# Regex 0.0
# Data_Processing 0.0
# Graphics 0.0
# Web_Apps 0.0
# Web_Dev 0.013943588880857007
# OS_Mgmt -0.0
# Network_System_Mgmt -0.0
# Interactive_Device_Design -0.0
# Obj/Img/Activity_Recognition 0.0
# Robotics 0.0
# NLP 0.024591373293213623
# Interface_Prototyping -0.0
# Vision_Sim 0.0
# Software_App -0.0
# AR/VR 0.0
# Installation_Work -0.0
# Member_CS_Community 0.0
# Comfortable_from_scratch -0.0
# Need_skeleton 0.0
# Comfortable_version_control 0.0
# Capable_programmer 0.0
# Accepted_by_peers 0.0

# %%
print(all_results[['Ruby', 'Overall_Rating']])
all_results[['Ruby', 'Overall_Rating']].describe()
# Out:
#      Ruby  Overall_Rating
# ID
# 111     3             4.0
# 112     0             6.0
# 113     0             3.0
# 211     0             5.0
# 212     1             7.0
# 214     0             6.0
# 411     3             6.0
# 412     1             2.0
# 413     2             4.0
# 414     2             3.0
# 512     1             7.0
# 613     1             5.0
# 614     0             6.0
# 711     0             6.0
# 713     2             7.0
# 813     0             3.0
# 811     0             4.0
#             Ruby  Overall_Rating
# count  17.000000       17.000000
# mean    0.941176        4.941176
# std     1.088037        1.599632
# min     0.000000        2.000000
# 25%     0.000000        4.000000
# 50%     1.000000        5.000000
# 75%     2.000000        6.000000
# max     3.000000        7.000000
